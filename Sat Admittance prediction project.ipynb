# %% [markdown]
# #        SAT  Admittance PREDICTION

# %% [markdown]
# # Step 1= load necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Step2= load dataset

# %%
rr=pd.read_csv("C:\\Users\\Dell\\OneDrive\\Desktop\\jup\\logestic regression\\2.01.Admittance.csv")
rr
# Out:
#       SAT Admitted
# 0    1363       No
# 1    1792      Yes
# 2    1954      Yes
# 3    1653       No
# 4    1593       No
# ..    ...      ...
# 163  1722      Yes
# 164  1750      Yes
# 165  1555       No
# 166  1524       No
# 167  1461       No
#
# [168 rows x 2 columns]

# %% [markdown]
# # plot graph

# %%
plt.scatter(rr["SAT"], rr["Admitted"])

# %% [markdown]
# # Step 3= Load Encoder

# %%
from sklearn.preprocessing import LabelEncoder
la=LabelEncoder()
rr["Admitted"]=la.fit_transform(rr["Admitted"])
rr
# Out:
#       SAT  Admitted
# 0    1363         0
# 1    1792         1
# 2    1954         1
# 3    1653         0
# 4    1593         0
# ..    ...       ...
# 163  1722         1
# 164  1750         1
# 165  1555         0
# 166  1524         0
# 167  1461         0
#
# [168 rows x 2 columns]

# %%
plt.scatter(df["SAT"], df["Admitted"])

# %% [markdown]
# # Split Input And Output

# %%
x = rr.iloc[:,0:1]
x
# Out:
#       SAT
# 0    1363
# 1    1792
# 2    1954
# 3    1653
# 4    1593
# ..    ...
# 163  1722
# 164  1750
# 165  1555
# 166  1524
# 167  1461
#
# [168 rows x 1 columns]

# %%
y=rr.iloc[:,-1]
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 163    1
# 164    1
# 165    0
# 166    0
# 167    0
# Name: Admitted, Length: 168, dtype: int64

# %% [markdown]
# # Step4:Split input output data in training and testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = 42)

# %% [markdown]
# # Step5: import algorithm

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %% [markdown]
# # Step 6: Model Train(.fit()) and Prediction(.predict())

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# # step7=Accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.9117647058823529

# %% [markdown]
# # stap8=Prediction Logistic Rregression Line Graph

# %%
sa = np.linspace(rr["SAT"].min(), rr["SAT"].max(), 100).reshape(-1,1)
s = model.predict_proba(sa)[:,1]
plt.scatter(rr["SAT"], rr["Admitted"])
plt.plot(sa,s)
# Out:
# C:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
